# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -u "/content/drive/MyDrive/VIT DATASET/VIT Stawberry.zip" -d "/content/drive/MyDrive/VIT DATASET/Stawberry_File"

print('\n\ndone!')
# Out:
# Archive:  /content/drive/MyDrive/VIT DATASET/VIT Stawberry.zip
#    creating: /content/drive/MyDrive/VIT DATASET/Stawberry_File/VIT Stawberry/
#    creating: /content/drive/MyDrive/VIT DATASET/Stawberry_File/VIT Stawberry/Angular LeafSpot/
#   inflating: /content/drive/MyDrive/VIT DATASET/Stawberry_File/VIT Stawberry/Angular LeafSpot/angular_leafspot1.rf.b2b20eacfb2678a6e1a0e0dde327c08b.jpg
#   inflating: /content/drive/MyDrive/VIT DATASET/Stawberry_File/VIT Stawberry/Angular LeafSpot/angular_leafspot10.rf.7de3b76d265d1c18a491aaf8f392e8b0.jpg
#   inflating: /content/drive/MyDrive/VIT DATASET/Stawberry_File/VIT Stawberry/Angular LeafSpot/angular_leafspot100.rf.2402638072cef5e93a219a4fb4ee7ead.jpg
#   inflating: /content/drive/MyDrive/VIT DATASET/Stawberry_File/VIT Stawberry/Angular LeafSpot/angular_leafspot100_jpg.rf.e11a401f5a51039509d715fcf728f33b.jpg
# ...
